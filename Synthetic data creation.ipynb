# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
import pandas as pd

# %%
# Coefficients (replace with your actual coefficients)
coefficients = [0.5, -1.2, 0.8]

# Intercept (replace with your actual intercept)
intercept = -1.5

def logistic_regression_equation(x, coefficients, intercept):
    z = intercept
    for i in range(len(coefficients)):
        z += coefficients[i] * x[:, i]
    return 1 / (1 + np.exp(-z))

# %%
# Number of data points
n_samples = 1000

# Number of independent variables
n_features = len(coefficients)

# Generate random independent variables
X = np.random.rand(n_samples, n_features)

# Calculate probabilities using the logistic regression equation
y_prob = logistic_regression_equation(X, coefficients, intercept)

# Convert probabilities to binary labels
y = (y_prob >= 0.5).astype(int)

# %%
df = pd.DataFrame(X)

# %%
df['y'] = y

# %%
df
# Out:
#             0         1         2  y
# 0    0.469559  0.325092  0.084480  0
# 1    0.425106  0.062750  0.578447  0
# 2    0.917627  0.570841  0.308404  0
# 3    0.528384  0.056459  0.017318  0
# 4    0.521441  0.985163  0.349180  0
# ..        ...       ...       ... ..
# 995  0.125173  0.023241  0.520536  0
# 996  0.424377  0.486269  0.080108  0
# 997  0.302202  0.830644  0.122047  0
# 998  0.685434  0.925424  0.958467  0
# 999  0.328994  0.165444  0.623613  0
#
# [1000 rows x 4 columns]

# %%
df['y'].value_counts()
# Out:
# 0    1000
# Name: y, dtype: int64
